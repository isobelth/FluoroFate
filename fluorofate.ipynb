# %% [markdown]
# # FluoroFate
#
# Napari-based GUI for fluorescence cell-death / cell-fate analysis.
# See [FluoroFate_README.md](FluoroFate_README.md) for full documentation.
#
# ## Pipeline
# 1. **Cellpose** segments brightfield frames into cell masks
# 2. **TrackMate** links cell identities across frames (headless via PyImageJ)
# 3. **Fluorescence thresholding** identifies positive regions per fluorophore (up to 3)
# 4. **Fate assignment** classifies cells in one of two modes:
#    - **Persistent** — first fluorophore to appear determines permanent fate (e.g. Annexin V / PI)
#    - **Snapshot** — per-frame classification by current active fluorophores (e.g. FUCCI)
# 5. **Outputs** — percentage trajectory plots, spatial trajectory plots, and cell-level CSVs (with positive area per fluorophore) at multiple frame-presence cutoffs
#
# ## Staged Workflow
# | Button | Description |
# |---|---|
# | **1) Run Segmentation** | Cellpose only → saves `masks_stack.tiff` |
# | **2) Run Tracking** | TrackMate only → saves linked labels + tracks CSV |

# %%
from fluorofate import launch

app = launch()
# Out:
# 2026-08-13 14:46:11,294 [INFO] OpenGL.acceleratesupport: No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 757x1147+960+276 (frame: 773x1186+952+245) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 757x1061+960+276 (frame: 773x1100+952+245) margins: 8, 31, 8, 8 minimum size: 288x503 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=304,542 maxtrack=0,0)
# 2026-08-13 14:46:13,132 [WARNING] vispy: QWindowsWindow::setGeometry: Unable to set geometry 757x1147+960+276 (frame: 773x1186+952+245) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 757x1061+960+276 (frame: 773x1100+952+245) margins: 8, 31, 8, 8 minimum size: 288x503 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=304,542 maxtrack=0,0)
# 2026-08-13 14:46:13,326 [INFO] fluorofate: FluoroFate ready.
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 2560x1145+0+23 (frame: 2576x1184-8-8) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 2560x1009+0+23 (frame: 2576x1048-8-8) margins: 8, 31, 8, 8 minimum size: 570x1145 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=586,1184 maxtrack=0,0)
# 2026-08-13 14:46:13,978 [WARNING] vispy: QWindowsWindow::setGeometry: Unable to set geometry 2560x1145+0+23 (frame: 2576x1184-8-8) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 2560x1009+0+23 (frame: 2576x1048-8-8) margins: 8, 31, 8, 8 minimum size: 570x1145 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=586,1184 maxtrack=0,0)
