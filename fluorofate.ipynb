# %% [markdown]
# # FluoroFate
#
# Napari-based GUI for fluorescence cell-death / cell-fate analysis.
# See [FluoroFate_README.md](FluoroFate_README.md) for full documentation.
#
# ## Pipeline
# 1. **Cellpose** segments brightfield frames into cell masks
# 2. **TrackMate** links cell identities across frames (headless via PyImageJ)
# 3. **Fluorescence thresholding** identifies positive regions per fluorophore (up to 3)
# 4. **Fate assignment** classifies cells in one of two modes:
#    - **Persistent** — first fluorophore to appear determines permanent fate (e.g. Annexin V / PI)
#    - **Snapshot** — per-frame classification by current active fluorophores (e.g. FUCCI)
# 5. **Outputs** — percentage trajectory plots, spatial trajectory plots, and cell-level CSVs (with positive area per fluorophore) at multiple frame-presence cutoffs
#
# ## Staged Workflow
# | Button | Description |
# |---|---|
# | **1) Run Segmentation** | Cellpose only → saves `masks_stack.tiff` |
# | **2) Run Tracking** | TrackMate only → saves linked labels + tracks CSV |

# %%
from fluorofate import launch

app = launch()
# Out:
# 2026-05-18 21:06:39,962 [INFO] OpenGL.acceleratesupport: No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1084x1635+640+330 (frame: 1102x1682+631+292) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1084x1175+640+330 (frame: 1102x1222+631+292) margins: 9, 38, 9, 9 minimum size: 289x521 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=307,568 maxtrack=0,0)
# 2026-05-18 21:06:46,352 [WARNING] vispy: QWindowsWindow::setGeometry: Unable to set geometry 1084x1635+640+330 (frame: 1102x1682+631+292) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1084x1175+640+330 (frame: 1102x1222+631+292) margins: 9, 38, 9, 9 minimum size: 289x521 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=307,568 maxtrack=0,0)
# ...
