# %% [markdown]
# # FluoroFate
#
# Napari-based GUI for fluorescence cell-death / cell-fate analysis.
# See [FluoroFate_README.md](FluoroFate_README.md) for full documentation.
#
# ## Pipeline
# 1. **Cellpose** segments brightfield frames into cell masks
# 2. **TrackMate** links cell identities across frames (headless via PyImageJ)
# 3. **Fluorescence thresholding** identifies positive regions per fluorophore (up to 3)
# 4. **Fate assignment** classifies cells in one of two modes:
#    - **Persistent** — first fluorophore to appear determines permanent fate (e.g. Annexin V / PI)
#    - **Snapshot** — per-frame classification by current active fluorophores (e.g. FUCCI)
# 5. **Outputs** — percentage trajectory plots, spatial trajectory plots, and cell-level CSVs (with positive area per fluorophore) at multiple frame-presence cutoffs
#
# ## Staged Workflow
# | Button | Description |
# |---|---|
# | **1) Run Segmentation** | Cellpose only → saves `masks_stack.tiff` |
# | **2) Run Tracking** | TrackMate only → saves linked labels + tracks CSV |

# %%
from fluorofate import launch

app = launch()
# Out:
# 2026-05-24 16:42:17,557 [INFO] OpenGL.acceleratesupport: No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# 2026-05-24 16:42:19,098 [INFO] fluorofate: FluoroFate ready.
# 2026-05-24 16:42:29,558 [INFO] fluorofate: Detected 3 channel(s) in smallest.tif.
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 2560x1135+0+23 (frame: 2576x1174-8-8) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 2560x1009+0+23 (frame: 2576x1048-8-8) margins: 8, 31, 8, 8 minimum size: 583x1135 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=599,1174 maxtrack=0,0)
# 2026-05-24 16:42:40,788 [WARNING] vispy: QWindowsWindow::setGeometry: Unable to set geometry 2560x1135+0+23 (frame: 2576x1174-8-8) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 2560x1009+0+23 (frame: 2576x1048-8-8) margins: 8, 31, 8, 8 minimum size: 583x1135 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=599,1174 maxtrack=0,0)
# 2026-05-24 16:42:50,902 [INFO] fluorofate: === Full pipeline ===
# 2026-05-24 16:42:50,902 [INFO] fluorofate: Working directory: C:\Users\isobe\Dropbox (Personal)\Shared_With_Me\kerrie_outputs\smallest
# 2026-05-24 16:42:50,954 [INFO] fluorofate: Loaded smallest.tif: 3 frame(s), 2 fluorophore(s).
# 2026-05-24 16:42:50,970 [INFO] segmentation: Cellpose: loading built-in model cpsam
# 2026-05-24 16:42:50,970 [WARNING] cellpose.models: model_type argument is not used in v4.0.1+. Ignoring this argument...
# 2026-05-24 16:42:51,052 [INFO] cellpose.core: ** TORCH CUDA version installed and working. **
# 2026-05-24 16:42:51,052 [INFO] cellpose.core: >>>> using GPU (CUDA)
# 2026-05-24 16:42:52,085 [INFO] cellpose.models: >>>> loading model C:\Users\isobe\.cellpose\models\cpsam
# 2026-05-24 16:43:01,796 [INFO] segmentation: Cellpose: estimated diameter from first frame = 61.3 px
# 2026-05-24 16:43:01,796 [INFO] segmentation: Cellpose: segmenting 3 frame(s) (diameter=61.3, flow_threshold=0.40, cellprob_threshold=0.00, min_size=15)
# 2026-05-24 16:43:09,227 [INFO] segmentation: Cellpose: frame 1/3 — 1156 cell(s) detected
# 2026-05-24 16:43:17,207 [INFO] segmentation: Cellpose: frame 2/3 — 1146 cell(s) detected
# 2026-05-24 16:43:25,856 [INFO] segmentation: Cellpose: frame 3/3 — 1190 cell(s) detected
# 2026-05-24 16:43:25,865 [INFO] segmentation: Cellpose: segmentation complete (3 frame(s))
# 2026-05-24 16:43:25,917 [INFO] fluorofate: Saved masks_stack.tiff
# 2026-05-24 16:43:26,103 [INFO] scyjava._jdk_fetch: Fetching zulu-jre:11...
# 2026-05-24 16:43:26,103 [INFO] jgo.util.java: Fetching Java 11 via cjdk (download mode)...
# 2026-05-24 16:43:26,182 [INFO] jgo.util.java: Using Java 11.0.31 (zulu-jre) at C:\Users\isobe\AppData\Local\cjdk\cache\v0\jdks\513dcabc2da6325ee798f26dc8ba03a447f426d4\zulu11.88.17-ca-jre11.0.31-win_x64\bin\java.exe
# 2026-05-24 16:43:29,625 [INFO] tracking: TrackMate: opening C:\Users\isobe\Dropbox (Personal)\Shared_With_Me\kerrie_outputs\smallest\masks_stack.tiff
# 2026-05-24 16:43:35,770 [WARNING] tracking: Track splitting was enabled but TrackMate produced no division edges; lineage_id will be trivial.
# 2026-05-24 16:44:01,230 [INFO] tracking: TrackMate: wrote 969 tracks to C:\Users\isobe\Dropbox (Personal)\Shared_With_Me\kerrie_outputs\smallest\linked_labels_trackmate.tiff
# 2026-05-24 16:44:01,256 [INFO] fluorofate: Tracked 969 cell(s), 2708 point(s), 0 division event(s).
# 2026-05-24 16:44:02,936 [INFO] fluorofate: Snapshot positive cells [Green]: 34 unique cell IDs across stack
# 2026-05-24 16:44:03,011 [INFO] fluorofate: Snapshot positive cells [Red]: 30 unique cell IDs across stack
# 2026-05-24 16:44:05,194 [INFO] fluorofate: Persistent fates: {'negative': np.int64(913), 'Green': np.int64(32), 'Red': np.int64(24)}
# 2026-05-24 16:44:08,704 [INFO] fluorofate: Snapshot categories: ['Green', 'Green+Red', 'Red', 'negative']
# 2026-05-24 16:44:09,041 [INFO] fluorofate: Saved per_frame_cells.csv (2683 rows).
# 2026-05-24 16:44:10,781 [INFO] fluorofate: Pipeline complete: smallest.tif
